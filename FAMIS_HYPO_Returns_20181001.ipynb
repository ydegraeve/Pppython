# %%
import os
import pyodbc
import numpy as np
import pandas as pd
from datetime import datetime

# %%
cnxn = pyodbc.connect('Driver={SQL Server Native Client 11.0};\
                       Server=lasr-sqldb-prd-im,17001;\
                       Database=IM_S_FAMIS_S;\
                       Trusted_Connection=yes;')

# %%
sql_query = """
select
FA.AsOfDate,
FA.ValueDecimal,
V.VehicleID as v_VehicleID,
VC.VehicleClassID as vc_VehicleClassID,
--V.AccountNumber as v_AccountNumber,
--VC.CUSIP as vc_CUSIP,
--VC.QuotronSymbol as vc_QuotronSymbol,
V.VehicleTypeName as v_VehicleTypeName,
V.AbbreviatedName as v_AbbreviatedName,
VC.AbbreviatedName as vc_AbbreviatedName,
FT.FactTypeCode as ft_FactTypeCode,
--FT.Name as ft_Name,
FST.Name as fst_Name
from MSS_S_FAMIS_S.dbo.FAMIS_MART_FactExt_CURRENT as FA
  inner join
     MSS_S_FAMIS_S.dbo.FAMIS_MART_FactTypeExt_CURRENT as FT
  on FA.FactTypeID=FT.FactTypeID
  left join
	MSS_S_FAMIS_S.dbo.FAMIS_MART_FactSubTypeExt_Current as FST
  on FA.FactSubTypeID=FST.FactSubTypeID
  inner join
     MSS_S_FAMIS_S.dbo.FAMIS_MART_VehicleExt_CURRENT as V
  on FA.VehicleID = V.VehicleID
  LEFT join 
     MSS_S_FAMIS_S.dbo.FAMIS_MART_VehicleClassExt_CURRENT as VC
  on FA.VehicleClassID = VC.VehicleClassID
where FT.FactTypeCode in ('ARRMOP','ARRNAV','TRMOP','TRNAV')
and FA.ValueDecimal is not NULL
"""

# Save the data 
df_famis = pd.read_sql(sql_query, cnxn)

# Close the connection with LASR
#THIS IS IMPORTANT ALWAYS DO THIS, ESPECIALLY IF CONNECTING TO PROD
cnxn.close()

# %%
print(df_famis.shape)
df_famis.head()
# Out:
# (11632094, 9)
#      AsOfDate  ValueDecimal  v_VehicleID  vc_VehicleClassID v_VehicleTypeName  \
# 0  2016-09-30      0.050500        23982            28271.0      Outside Fund
# 1  2014-06-30      0.067600        22759            16949.0      Outside Fund
# 2  2016-10-31      2.278697        10028            10503.0     American Fund
# 3  2016-10-31      0.050700        24721            21871.0      Outside Fund
# 4  2016-09-30      0.099000        22876            21129.0      Outside Fund
#
#   v_AbbreviatedName vc_AbbreviatedName ft_FactTypeCode   fst_Name
# 0              None               None          ARRNAV   5 Years
# 1              None               None          ARRNAV   Lifetime
# 2              AHIM             AHIM-A           TRMOP  Lifetime
# 3              None               None          ARRNAV   Lifetime
# 4              None               None          ARRNAV   Lifetime

# %%
df_1stsold = pd.read_csv('FAMIS_MART_VehicleClassDateExt.csv')
print(df_1stsold.shape)

#Keep only the Sold Date records
df_1stsold = df_1stsold[df_1stsold['DateType'] == 'Initial Sold Date']
df_1stsold.drop(['DateType'], axis=1, inplace=True)

df_1stsold.rename(columns={'Date': 'FirstSoldDt'}, inplace=True)

print(df_1stsold.shape)
df_1stsold.head()
# Out:
# (37679, 4)
# (1338, 3)
#    VehicleClassDateID  VehicleClassID FirstSoldDt
# 0               10001           10000  07/31/1952
# 1               10002           10001  03/15/2000
# 2               10003           10002  03/15/2001
# 3               10004           10003  03/15/2001
# 4               10005           10004  08/05/2008

# %%
format_str = '%m/%d/%Y' # The format

df_famis['AsOfDate'] = df_famis['AsOfDate'].apply(lambda dt: dt.replace(day=1))
df_1stsold['FirstSoldDt_dt'] = df_1stsold['FirstSoldDt'].apply(lambda dt: datetime.strptime(dt, format_str))
#df_1stsold['FirstSoldDt'] = df_1stsold['FirstSoldDt'].apply(lambda dt: dt.replace(day=1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-faefba93074e> in <module>()
#       1 df_famis['AsOfDate'] = df_famis['AsOfDate'].apply(lambda dt: dt.replace(day=1))
# ----> 2 df_1stsold['FirstSoldDt'] = df_1stsold['FirstSoldDt'].apply(lambda dt: dt.replace(day=1))
#
# C:\Users\KPMYAD\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\src\inference.pyx in pandas._libs.lib.map_infer (pandas\_libs\lib.c:66440)()
#
# <ipython-input-7-faefba93074e> in <lambda>(dt)
#       1 df_famis['AsOfDate'] = df_famis['AsOfDate'].apply(lambda dt: dt.replace(day=1))
# ----> 2 df_1stsold['FirstSoldDt'] = df_1stsold['FirstSoldDt'].apply(lambda dt: dt.replace(day=1))
#
# TypeError: replace() takes no keyword arguments

# %%
#join first sold date to extract
df_combo = df_famis.merge(df_1stsold, left_on=['vc_VehicleClassID'], right_on= ['VehicleClassID'], how='left')
print(df_combo.shape)
df_combo.head()
# Out:
# (11632094, 13)
#      AsOfDate  ValueDecimal  v_VehicleID vc_VehicleClassID v_VehicleTypeName  \
# 0  2016-09-01      0.050500        23982             28271      Outside Fund
# 1  2014-06-01      0.067600        22759             16949      Outside Fund
# 2  2016-10-01      2.278697        10028             10503     American Fund
# 3  2016-10-01      0.050700        24721             21871      Outside Fund
# 4  2016-09-01      0.099000        22876             21129      Outside Fund
#
#   v_AbbreviatedName vc_AbbreviatedName ft_FactTypeCode   fst_Name  \
# 0              None               None          ARRNAV   5 Years
# 1              None               None          ARRNAV   Lifetime
# 2              AHIM             AHIM-A           TRMOP  Lifetime
# 3              None               None          ARRNAV   Lifetime
# 4              None               None          ARRNAV   Lifetime
#
#    VehicleClassDateID  VehicleClassID FirstSoldDt FirstSoldDt_dt
# 0                 NaN             NaN         NaN            NaT
# 1                 NaN             NaN         NaN            NaT
# 2             10502.0         10503.0  09/26/1994     1994-09-26
# 3                 NaN             NaN         NaN            NaT
# 4                 NaN             NaN         NaN            NaT

# %%
df_combo.drop(['VehicleClassID','v_VehicleID','vc_VehicleClassID', 'VehicleClassDateID','FirstSoldDt'], axis=1, inplace=True)
df_combo.head()
# Out:
#      AsOfDate  ValueDecimal v_VehicleTypeName v_AbbreviatedName  \
# 0  2016-09-01      0.050500      Outside Fund              None
# 1  2014-06-01      0.067600      Outside Fund              None
# 2  2016-10-01      2.278697     American Fund              AHIM
# 3  2016-10-01      0.050700      Outside Fund              None
# 4  2016-09-01      0.099000      Outside Fund              None
#
#   vc_AbbreviatedName ft_FactTypeCode   fst_Name FirstSoldDt_dt
# 0               None          ARRNAV   5 Years             NaT
# 1               None          ARRNAV   Lifetime            NaT
# 2             AHIM-A           TRMOP  Lifetime      1994-09-26
# 3               None          ARRNAV   Lifetime            NaT
# 4               None          ARRNAV   Lifetime            NaT

# %%
df_combo['IsHypo'] = df_combo.apply(lambda row: row.AsOfDate < datetime.date(row.FirstSoldDt_dt), axis=1)
#df_combo['IsHypo'] = (df_combo.AsOfDate < df_combo.FirstSoldDt_dt)
df_combo.head()
# Out:
#      AsOfDate  ValueDecimal v_VehicleTypeName v_AbbreviatedName  \
# 0  2016-09-01      0.050500      Outside Fund              None
# 1  2014-06-01      0.067600      Outside Fund              None
# 2  2016-10-01      2.278697     American Fund              AHIM
# 3  2016-10-01      0.050700      Outside Fund              None
# 4  2016-09-01      0.099000      Outside Fund              None
#
#   vc_AbbreviatedName ft_FactTypeCode   fst_Name FirstSoldDt_dt  IsHypo
# 0               None          ARRNAV   5 Years             NaT   False
# 1               None          ARRNAV   Lifetime            NaT   False
# 2             AHIM-A           TRMOP  Lifetime      1994-09-26   False
# 3               None          ARRNAV   Lifetime            NaT   False
# 4               None          ARRNAV   Lifetime            NaT   False

# %%
#check the amcap example is working
test=df_combo[(df_combo['vc_AbbreviatedName'] == 'AMCAP-R6') & (df_combo['AsOfDate'] <= datetime.strptime('01012010', "%d%m%Y").date())]
test
# Out:
#            AsOfDate  ValueDecimal v_VehicleTypeName v_AbbreviatedName  \
# 6728251  2009-05-01       -0.0614     American Fund             AMCAP
# 6728265  2009-05-01        0.0228     American Fund             AMCAP
# 6728279  2009-06-01       -0.0624     American Fund             AMCAP
# 6728293  2009-06-01        0.0163     American Fund             AMCAP
# 6728307  2009-07-01       -0.0313     American Fund             AMCAP
# 6728321  2009-07-01        0.0279     American Fund             AMCAP
# 6728335  2009-08-01       -0.0274     American Fund             AMCAP
# 6728349  2009-08-01        0.0330     American Fund             AMCAP
# 6728363  2009-09-01       -0.0224     American Fund             AMCAP
# 6728377  2009-09-01        0.0372     American Fund             AMCAP
# 6728391  2009-10-01       -0.0416     American Fund             AMCAP
# 6728405  2009-10-01        0.0320     American Fund             AMCAP
# 6728419  2009-11-01       -0.0320     American Fund             AMCAP
# 6728433  2009-11-01        0.0327     American Fund             AMCAP
# 6728447  2009-12-01       -0.0193     American Fund             AMCAP
# 6735713  2009-05-01       -0.0105     American Fund             AMCAP
# 6735727  2009-05-01        0.0840     American Fund             AMCAP
# 6735741  2009-06-01       -0.0126     American Fund             AMCAP
# 6735755  2009-06-01        0.0866     American Fund             AMCAP
# 6735769  2009-07-01        0.0115     American Fund             AMCAP
# 6735783  2009-07-01        0.0901     American Fund             AMCAP
# 6735797  2009-08-01        0.0209     American Fund             AMCAP
# 6735811  2009-08-01        0.0892     American Fund             AMCAP
# 6735825  2009-09-01        0.0238     American Fund             AMCAP
# 6735839  2009-09-01        0.0940     American Fund             AMCAP
# 6735853  2009-10-01        0.0153     American Fund             AMCAP
# 6735867  2009-10-01        0.0909     American Fund             AMCAP
# 6735881  2009-11-01        0.0191     American Fund             AMCAP
# 6735895  2009-11-01        0.0969     American Fund             AMCAP
# 6735909  2009-12-01        0.0199     American Fund             AMCAP
# ...             ...           ...               ...               ...
# 8229296  1989-04-01        0.2023     American Fund             AMCAP
# 8229309  1989-04-01        1.1421     American Fund             AMCAP
# 8229322  1989-05-01        0.2657     American Fund             AMCAP
# 8229335  1989-05-01        1.3556     American Fund             AMCAP
# 8242283  1989-01-01        0.0774     American Fund             AMCAP
# 8242296  1989-02-01       -0.0118     American Fund             AMCAP
# 8242309  1989-02-01        0.1061     American Fund             AMCAP
# 8242322  1989-02-01        0.1283     American Fund             AMCAP
# 8242335  1989-02-01        0.0647     American Fund             AMCAP
# 8242348  1989-03-01        0.0155     American Fund             AMCAP
# 8242361  1989-03-01        0.0812     American Fund             AMCAP
# 8242374  1989-03-01        0.1011     American Fund             AMCAP
# 8242387  1989-03-01        0.0812     American Fund             AMCAP
# 8242400  1989-04-01        0.0576     American Fund             AMCAP
# 8242413  1989-04-01        0.0613     American Fund             AMCAP
# 8242426  1989-04-01        0.1653     American Fund             AMCAP
# 8242439  1989-04-01        0.0576     American Fund             AMCAP
# 8242452  1989-05-01        0.0457     American Fund             AMCAP
# 8242465  1989-05-01        0.1231     American Fund             AMCAP
# 8242478  1989-05-01        0.2423     American Fund             AMCAP
# 8292281  1989-01-01       13.2514     American Fund             AMCAP
# 8292294  1989-02-01       10.7285     American Fund             AMCAP
# 8292307  1989-02-01        9.7899     American Fund             AMCAP
# 8292320  1989-02-01       13.0829     American Fund             AMCAP
# 8292333  1989-03-01       11.2327     American Fund             AMCAP
# 8292346  1989-03-01        9.7053     American Fund             AMCAP
# 8292359  1989-03-01       13.3014     American Fund             AMCAP
# 8292372  1989-04-01       12.4809     American Fund             AMCAP
# 8292385  1989-04-01       10.1422     American Fund             AMCAP
# 8292398  1989-04-01       14.1253     American Fund             AMCAP
#
#         vc_AbbreviatedName ft_FactTypeCode         fst_Name FirstSoldDt_dt  \
# 6728251           AMCAP-R6          ARRNAV          3 Years     2009-05-01
# 6728265           AMCAP-R6          ARRNAV         10 Years     2009-05-01
# 6728279           AMCAP-R6          ARRNAV          3 Years     2009-05-01
# 6728293           AMCAP-R6          ARRNAV         10 Years     2009-05-01
# 6728307           AMCAP-R6          ARRNAV          3 Years     2009-05-01
# 6728321           AMCAP-R6          ARRNAV         10 Years     2009-05-01
# 6728335           AMCAP-R6          ARRNAV          3 Years     2009-05-01
# 6728349           AMCAP-R6          ARRNAV         10 Years     2009-05-01
# 6728363           AMCAP-R6          ARRNAV          3 Years     2009-05-01
# 6728377           AMCAP-R6          ARRNAV         10 Years     2009-05-01
# 6728391           AMCAP-R6          ARRNAV          3 Years     2009-05-01
# 6728405           AMCAP-R6          ARRNAV         10 Years     2009-05-01
# 6728419           AMCAP-R6          ARRNAV          3 Years     2009-05-01
# 6728433           AMCAP-R6          ARRNAV         10 Years     2009-05-01
# 6728447           AMCAP-R6          ARRNAV          3 Years     2009-05-01
# 6735713           AMCAP-R6          ARRNAV         5 Years      2009-05-01
# 6735727           AMCAP-R6          ARRNAV         15 Years     2009-05-01
# 6735741           AMCAP-R6          ARRNAV         5 Years      2009-05-01
# 6735755           AMCAP-R6          ARRNAV         15 Years     2009-05-01
# 6735769           AMCAP-R6          ARRNAV         5 Years      2009-05-01
# 6735783           AMCAP-R6          ARRNAV         15 Years     2009-05-01
# 6735797           AMCAP-R6          ARRNAV         5 Years      2009-05-01
# 6735811           AMCAP-R6          ARRNAV         15 Years     2009-05-01
# 6735825           AMCAP-R6          ARRNAV         5 Years      2009-05-01
# 6735839           AMCAP-R6          ARRNAV         15 Years     2009-05-01
# 6735853           AMCAP-R6          ARRNAV         5 Years      2009-05-01
# 6735867           AMCAP-R6          ARRNAV         15 Years     2009-05-01
# 6735881           AMCAP-R6          ARRNAV         5 Years      2009-05-01
# 6735895           AMCAP-R6          ARRNAV         15 Years     2009-05-01
# 6735909           AMCAP-R6          ARRNAV         5 Years      2009-05-01
# ...                    ...             ...              ...            ...
# 8229296           AMCAP-R6           TRNAV           1 Year     2009-05-01
# 8229309           AMCAP-R6           TRNAV          5 Years     2009-05-01
# 8229322           AMCAP-R6           TRNAV           1 Year     2009-05-01
# 8229335           AMCAP-R6           TRNAV          5 Years     2009-05-01
# 8242283           AMCAP-R6           TRNAV  Quarter to Date     2009-05-01
# 8242296           AMCAP-R6           TRNAV          1 Month     2009-05-01
# 8242309           AMCAP-R6           TRNAV         3 Months     2009-05-01
# 8242322           AMCAP-R6           TRNAV         6 Months     2009-05-01
# 8242335           AMCAP-R6           TRNAV  Quarter to Date     2009-05-01
# 8242348           AMCAP-R6           TRNAV          1 Month     2009-05-01
# 8242361           AMCAP-R6           TRNAV         3 Months     2009-05-01
# 8242374           AMCAP-R6           TRNAV         6 Months     2009-05-01
# 8242387           AMCAP-R6           TRNAV  Quarter to Date     2009-05-01
# 8242400           AMCAP-R6           TRNAV          1 Month     2009-05-01
# 8242413           AMCAP-R6           TRNAV         3 Months     2009-05-01
# 8242426           AMCAP-R6           TRNAV         6 Months     2009-05-01
# 8242439           AMCAP-R6           TRNAV  Quarter to Date     2009-05-01
# 8242452           AMCAP-R6           TRNAV          1 Month     2009-05-01
# 8242465           AMCAP-R6           TRNAV         3 Months     2009-05-01
# 8242478           AMCAP-R6           TRNAV         6 Months     2009-05-01
# 8292281           AMCAP-R6           TRNAV         Lifetime     2009-05-01
# 8292294           AMCAP-R6           TRNAV        15 Years      2009-05-01
# 8292307           AMCAP-R6           TRNAV         20 Years     2009-05-01
# 8292320           AMCAP-R6           TRNAV         Lifetime     2009-05-01
# 8292333           AMCAP-R6           TRNAV        15 Years      2009-05-01
# 8292346           AMCAP-R6           TRNAV         20 Years     2009-05-01
# 8292359           AMCAP-R6           TRNAV         Lifetime     2009-05-01
# 8292372           AMCAP-R6           TRNAV        15 Years      2009-05-01
# 8292385           AMCAP-R6           TRNAV         20 Years     2009-05-01
# 8292398           AMCAP-R6           TRNAV         Lifetime     2009-05-01
#
#          IsHypo
# 6728251   False
# 6728265   False
# 6728279   False
# 6728293   False
# 6728307   False
# 6728321   False
# 6728335   False
# 6728349   False
# 6728363   False
# 6728377   False
# 6728391   False
# 6728405   False
# 6728419   False
# 6728433   False
# 6728447   False
# 6735713   False
# 6735727   False
# 6735741   False
# 6735755   False
# 6735769   False
# 6735783   False
# 6735797   False
# 6735811   False
# 6735825   False
# 6735839   False
# 6735853   False
# 6735867   False
# 6735881   False
# 6735895   False
# 6735909   False
# ...         ...
# 8229296    True
# 8229309    True
# 8229322    True
# 8229335    True
# 8242283    True
# 8242296    True
# 8242309    True
# 8242322    True
# 8242335    True
# 8242348    True
# 8242361    True
# 8242374    True
# 8242387    True
# 8242400    True
# 8242413    True
# 8242426    True
# 8242439    True
# 8242452    True
# 8242465    True
# 8242478    True
# 8292281    True
# 8292294    True
# 8292307    True
# 8292320    True
# 8292333    True
# 8292346    True
# 8292359    True
# 8292372    True
# 8292385    True
# 8292398    True
#
# [15854 rows x 9 columns]

# %%
#output the summarized version
df_combo.to_csv('FAMIS_Hypo_20181002.csv')
