# %%
import os
import pyodbc
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cnxn = pyodbc.connect('Driver={SQL Server Native Client 11.0};\
                       Server=lasr-sqldb-prd-im,17001;\
                       Database=IM_S_FAMIS_S;\
                       Trusted_Connection=yes;')

# %%
sql_query = """
select
FA.AsOfDate,
FA.ValueDecimal,
V.VehicleID as v_VehicleID,
VC.VehicleClassID as vc_VehicleClassID,
V.AccountNumber as v_AccountNumber,
VC.CUSIP as vc_CUSIP,
VC.QuotronSymbol as vc_QuotronSymbol,
V.VehicleTypeName as v_VehicleTypeName,
V.AbbreviatedName as v_AbbreviatedName,
VC.AbbreviatedName as vc_AbbreviatedName,
FT.FactTypeCode as ft_FactTypeCode,
FT.Name as ft_Name,
FST.Name as fst_Name
from MSS_S_FAMIS_S.dbo.FAMIS_MART_FactExt_CURRENT as FA
  inner join
     MSS_S_FAMIS_S.dbo.FAMIS_MART_FactTypeExt_CURRENT as FT
  on FA.FactTypeID=FT.FactTypeID
  left join
	MSS_S_FAMIS_S.dbo.FAMIS_MART_FactSubTypeExt_Current as FST
  on FA.FactSubTypeID=FST.FactSubTypeID
  inner join
     MSS_S_FAMIS_S.dbo.FAMIS_MART_VehicleExt_CURRENT as V
  on FA.VehicleID = V.VehicleID
  LEFT join 
     MSS_S_FAMIS_S.dbo.FAMIS_MART_VehicleClassExt_CURRENT as VC
  on FA.VehicleClassID = VC.VehicleClassID
where FT.FactTypeCode in ('ALPHA','BETA','CORR_ACWI','CORR_SNP','ARRMOP','ARRNAV','TRMOP','TRNAV','RSGA','RSG','ILAF','RILC','ILGVA','ILOF','RSNFA','RSNF','RNSA','RSA','FR','RSQ','SRAT','SRILAF','SDF','SDILAF')
"""

# Save the data 
data = pd.read_sql(sql_query, cnxn)

# Close the connection with LASR
#THIS IS IMPORTANT ALWAYS DO THIS, ESPECIALLY IF CONNECTING TO PROD
cnxn.close()

# %%
print(data.shape)
data.head()
# Out:
# (12977852, 13)
#      AsOfDate  ValueDecimal  v_VehicleID  vc_VehicleClassID v_AccountNumber  \
# 0  2016-10-31      0.138300        25488            33462.0            None
# 1  2018-07-31     -0.011431        10031            10542.0        11000043
# 2  2017-03-31      0.047801        10037            10644.0        11000064
# 3  2014-11-30      0.009100        27876            34143.0            None
# 4  2016-11-30      0.131200        25361            12031.0            None
#
#       vc_CUSIP vc_QuotronSymbol v_VehicleTypeName v_AbbreviatedName  \
# 0    72201M586            PCKPX      Outside Fund              None
# 1  532726 30 4            LTXCX     American Fund              LTEX
# 2  02631C 84 1            BBDTX     American Fund            AFTD25
# 3    38145L646            GDIAX      Outside Fund              None
# 4    641224134            NVAAX      Outside Fund              None
#
#   vc_AbbreviatedName ft_FactTypeCode  \
# 0               None          ARRNAV
# 1             LTEX-C           TRMOP
# 2           AFTD25-B          ARRMOP
# 3               None          ARRNAV
# 4               None          ARRNAV
#
#                                     ft_Name      fst_Name
# 0             Returns: Average Annual (NAV)      5 Years
# 1                 Returns: Cumulative (MOP)  Year to Date
# 2  Returns: Average Annual (MOP or w/ CDSC)      Lifetime
# 3             Returns: Average Annual (NAV)        1 Year
# 4             Returns: Average Annual (NAV)      5 Years

# %%
data.v_VehicleTypeName.unique()
# Out:
# array(['Outside Fund', 'American Fund', 'Benchmark', 'AFIS Fund',
#        'CIAM Fund', 'PCS Fund', 'Composite'], dtype=object)

# %%
data['postdt_new'] = data['AsOfDate'].apply(lambda dt: dt.replace(day=1))
data.head()
# Out:
#      AsOfDate  ValueDecimal  v_VehicleID  vc_VehicleClassID v_AccountNumber  \
# 0  2016-10-31      0.138300        25488            33462.0            None
# 1  2018-07-31     -0.011431        10031            10542.0        11000043
# 2  2017-03-31      0.047801        10037            10644.0        11000064
# 3  2014-11-30      0.009100        27876            34143.0            None
# 4  2016-11-30      0.131200        25361            12031.0            None
#
#       vc_CUSIP vc_QuotronSymbol v_VehicleTypeName v_AbbreviatedName  \
# 0    72201M586            PCKPX      Outside Fund              None
# 1  532726 30 4            LTXCX     American Fund              LTEX
# 2  02631C 84 1            BBDTX     American Fund            AFTD25
# 3    38145L646            GDIAX      Outside Fund              None
# 4    641224134            NVAAX      Outside Fund              None
#
#   vc_AbbreviatedName ft_FactTypeCode  \
# 0               None          ARRNAV
# 1             LTEX-C           TRMOP
# 2           AFTD25-B          ARRMOP
# 3               None          ARRNAV
# 4               None          ARRNAV
#
#                                     ft_Name      fst_Name  postdt_new
# 0             Returns: Average Annual (NAV)      5 Years   2016-10-01
# 1                 Returns: Cumulative (MOP)  Year to Date  2018-07-01
# 2  Returns: Average Annual (MOP or w/ CDSC)      Lifetime  2017-03-01
# 3             Returns: Average Annual (NAV)        1 Year  2014-11-01
# 4             Returns: Average Annual (NAV)      5 Years   2016-11-01

# %%
data['dummy'] = 1
data['v_AccountNumber'].fillna('NA')
print(data.shape)
data.head()
# Out:
# (12977852, 15)
#      AsOfDate  ValueDecimal  v_VehicleID  vc_VehicleClassID v_AccountNumber  \
# 0  2014-08-31     -0.035000        22980            14381.0            None
# 1  2017-12-31      0.030565        10031            10542.0        11000043
# 2  1980-02-29     -0.063200        10161                NaN            None
# 3  2014-08-31      0.259300        23128            21147.0            None
# 4  2011-09-30     94.730000        10085            11163.0        11000070
#
#       vc_CUSIP vc_QuotronSymbol v_VehicleTypeName v_AbbreviatedName  \
# 0    31618H663            FLFTX      Outside Fund              None
# 1  532726 30 4            LTXCX     American Fund              LTEX
# 2         None             None         Benchmark   FTSE Credit Idx
# 3    921913208            VGIAX      Outside Fund              None
# 4  030372 60 1             None         AFIS Fund              VIAA
#
#   vc_AbbreviatedName ft_FactTypeCode  \
# 0               None          ARRNAV
# 1             LTEX-C          ARRMOP
# 2               None           TRNAV
# 3               None          ARRNAV
# 4             VIAA-1             RSQ
#
#                                     ft_Name                       fst_Name  \
# 0             Returns: Average Annual (NAV)                       Lifetime
# 1  Returns: Average Annual (MOP or w/ CDSC)                      20 Years
# 2                 Returns: Cumulative (NAV)                        1 Month
# 3             Returns: Average Annual (NAV)                         1 Year
# 4                                 R-Squared  Morningstar R-Squared 10 Year
#
#    postdt_new  dummy
# 0  2014-08-01      1
# 1  2017-12-01      1
# 2  1980-02-01      1
# 3  2014-08-01      1
# 4  2011-09-01      1

# %%
# df_grouped = data.groupby(['postdt_new', 'v_VehicleTypeName', 'v_AbbreviatedName', 'vc_AbbreviatedName','ft_FactTypeCode','ft_Name','fst_Name'])['dummy'].sum().reset_index()
# print(df_grouped.shape)
# df_grouped.head()
# Out:
# (8907087, 8)
#    postdt_new v_VehicleTypeName v_AbbreviatedName vc_AbbreviatedName  \
# 0  1933-12-01     American Fund               ICA           ICA-529A
# 1  1933-12-01     American Fund               ICA           ICA-529A
# 2  1933-12-01     American Fund               ICA           ICA-529B
# 3  1933-12-01     American Fund               ICA           ICA-529B
# 4  1933-12-01     American Fund               ICA           ICA-529C
#
#   ft_FactTypeCode                    ft_Name   fst_Name  dummy
# 0           TRMOP  Returns: Cumulative (MOP)  Lifetime       1
# 1           TRNAV  Returns: Cumulative (NAV)   Lifetime      1
# 2           TRMOP  Returns: Cumulative (MOP)  Lifetime       1
# 3           TRNAV  Returns: Cumulative (NAV)   Lifetime      1
# 4           TRMOP  Returns: Cumulative (MOP)  Lifetime       1

# %%
# df_grouped.rename(columns={'dummy':'FundSC_cnt'}, inplace=True)
# df_grouped.head()
# Out:
#    postdt_new v_VehicleTypeName v_AbbreviatedName vc_AbbreviatedName  \
# 0  1933-12-01     American Fund               ICA           ICA-529A
# 1  1933-12-01     American Fund               ICA           ICA-529A
# 2  1933-12-01     American Fund               ICA           ICA-529B
# 3  1933-12-01     American Fund               ICA           ICA-529B
# 4  1933-12-01     American Fund               ICA           ICA-529C
#
#   ft_FactTypeCode                    ft_Name   fst_Name  FundSC_cnt
# 0           TRMOP  Returns: Cumulative (MOP)  Lifetime            1
# 1           TRNAV  Returns: Cumulative (NAV)   Lifetime           1
# 2           TRMOP  Returns: Cumulative (MOP)  Lifetime            1
# 3           TRNAV  Returns: Cumulative (NAV)   Lifetime           1
# 4           TRMOP  Returns: Cumulative (MOP)  Lifetime            1

# %%
data_slim =data[['postdt_new', 'v_VehicleTypeName', 'v_AbbreviatedName', 'vc_AbbreviatedName','ft_FactTypeCode','ft_Name','fst_Name']]

# %%
data_slim.to_csv('1_1_MSS_FAMIS_v2.csv')

# %%
#data_slim_grouped =data[['postdt_new', 'v_VehicleTypeName', 'v_AbbreviatedName', 'vc_AbbreviatedName','ft_FactTypeCode','ft_Name','fst_Name','dummy']].groupby(['postdt_new', 'v_VehicleTypeName', 'v_AbbreviatedName', 'ft_FactTypeCode','ft_Name','fst_Name'])['dummy'].sum().reset_index()

# %%
data_slim_grouped.dummy.sum()
# Out:
# 10595186

# %%
test=data[data['vc_AbbreviatedName'] == 'AMCAP-R6']

# %%
print(test.v_VehicleID.unique())
print(test.vc_VehicleClassID.unique())
# Out:
# [10001]
# [ 10036.]
